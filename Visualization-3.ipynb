# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset_preprocessed.csv')
df.head()
# Out:
#             Jurusan Jenis transportasi yang digunakan  \
# 0  Computer Science                     Motor pribadi
# 1  Computer Science                     Motor pribadi
# 2  Computer Science                     Motor pribadi
# 3  Computer Science                     Motor pribadi
# 4  Computer Science                     Motor pribadi
#
#          Permasalahan fasilitas parkir Keamanan fasilitas parkir Biaya parkir  \
# 0                   Antri keluar masuk                      Aman          Iya
# 1  Antri keluar masuk, bayar nya mahal                      Aman          Iya
# 2      Parkir penuh, Tempatnya terbuka                      Aman          Iya
# 3     Parkir penuh, Antri keluar masuk                      Aman        Tidak
# 4      Parkir penuh, Tempatnya terbuka                Tidak Aman        Tidak
#
#    Kepuasan fasilitas parkir Tangga/lift yang paling sering dipakai  \
# 0                          3                           Tangga Biasa
# 1                          2                                   Lift
# 2                          3                                   Lift
# 3                          2                         Tangga Darurat
# 4                          1                         Tangga Darurat
#
#   Alasan menggunakan fasilitas tangga/lift  Kepuasan fasilitas tangga/lift  \
# 0                 Tidak mau menunggu/antri                               3
# 1                              Lebih cepat                               5
# 2                   Lebih nyaman digunakan                               5
# 3                              Lebih cepat                               3
# 4                              Lebih cepat                               3
#
#   Lokasi beli makanan  ... Kebersihan toilet  Kepuasan fasilitas toilet  \
# 0     Di dalam kampus  ...             Sudah                          5
# 1      Di luar kampus  ...             Sudah                          6
# 2     Di dalam kampus  ...             Sudah                          4
# 3     Di dalam kampus  ...             Sudah                          5
# 4      Di luar kampus  ...             Sudah                          4
#
#   Kepuasan secara umum Permasalahan fasilitas parkir 1  \
# 0                    4              Antri keluar masuk
# 1                    4              Antri keluar masuk
# 2                    4                    Parkir penuh
# 3                    4                    Parkir penuh
# 4                    4                    Parkir penuh
#
#    Permasalahan fasilitas parkir 2  \
# 0                              NaN
# 1                              NaN
# 2                Tempatnya terbuka
# 3               Antri keluar masuk
# 4                Tempatnya terbuka
#
#        Permasalahan fasilitas discussion room 1  \
# 0  Ketersediaan jam yang bisa di booking kurang
# 1                     Jumlahnya ruangan sedikit
# 2                     Jumlahnya ruangan sedikit
# 3  Ketersediaan jam yang bisa di booking kurang
# 4                     Jumlahnya ruangan sedikit
#
#        Permasalahan fasilitas discussion room 2  \
# 0                                           NaN
# 1  Ketersediaan jam yang bisa di booking kurang
# 2  Ketersediaan jam yang bisa di booking kurang
# 3                                           NaN
# 4  Ketersediaan jam yang bisa di booking kurang
#
#             Permasalahan fasilitas discussion room 3  \
# 0                                                NaN
# 1                                                NaN
# 2  Discussion room yang di booking tapi tidak dig...
# 3                                                NaN
# 4                                                NaN
#
#   Alasan memilih beli di tempat itu 1  Alasan memilih beli di tempat itu 2
# 0                Lebih banyak variasi                          Lebih dekat
# 1                Lebih banyak variasi                          Lebih murah
# 2                         Lebih dekat                                  NaN
# 3                          Kebersihan                          Lebih dekat
# 4                Lebih banyak variasi                          Tidak antri
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['Jurusan', 'Jenis transportasi yang digunakan',
#        'Permasalahan fasilitas parkir', 'Keamanan fasilitas parkir',
#        'Biaya parkir', 'Kepuasan fasilitas parkir',
#        'Tangga/lift yang paling sering dipakai',
#        'Alasan menggunakan fasilitas tangga/lift',
#        'Kepuasan fasilitas tangga/lift', 'Lokasi beli makanan',
#        'Alasan memilih beli di tempat itu', 'Kepuasan fasilitas kantin',
#        'Frekuensi penggunaan discussion room',
#        'Permasalahan fasilitas discussion room',
#        'Kepuasan fasilitas discussion room', 'Kecepatan dan kestabilan wifi',
#        'Kepuasan fasilitas internet', 'Kapasitas toilet', 'Kebersihan toilet',
#        'Kepuasan fasilitas toilet', 'Kepuasan secara umum',
#        'Permasalahan fasilitas parkir 1', 'Permasalahan fasilitas parkir 2',
#        'Permasalahan fasilitas discussion room 1',
#        'Permasalahan fasilitas discussion room 2',
#        'Permasalahan fasilitas discussion room 3',
#        'Alasan memilih beli di tempat itu 1',
#        'Alasan memilih beli di tempat itu 2'],
#       dtype='object')

# %%
sns.heatmap(df[['Kepuasan fasilitas parkir',
                'Kepuasan fasilitas tangga/lift', 
                'Kepuasan fasilitas kantin',
                'Kepuasan fasilitas discussion room',
                'Kepuasan fasilitas internet',
                'Kepuasan fasilitas toilet',
                'Kepuasan secara umum'
                ]].corr(), annot=True)
plt.title("Heatmap untuk semua responden")
plt.show()

# %%
sns.heatmap(df[['Kepuasan fasilitas parkir',
                'Kepuasan fasilitas tangga/lift', 
                'Kepuasan fasilitas kantin',
                'Kepuasan fasilitas discussion room',
                'Kepuasan fasilitas internet',
                'Kepuasan fasilitas toilet',
                'Kepuasan secara umum'
                ]][df['Jurusan'] == "Computer Science"].corr(), annot=True)

plt.title("Heatmap untuk responden dari jurusan Computer Science")
plt.show()

# %%
sns.heatmap(df[['Kepuasan fasilitas parkir',
                'Kepuasan fasilitas tangga/lift', 
                'Kepuasan fasilitas kantin',
                'Kepuasan fasilitas discussion room',
                'Kepuasan fasilitas internet',
                'Kepuasan fasilitas toilet',
                'Kepuasan secara umum'
                ]][df['Jurusan'] == "Visual Communication Design"].corr(), annot=True)

plt.title("Heatmap untuk responden dari jurusan Visual Communication Design")
plt.show()

# %% [markdown]
# # Violinplot

# %%
data = pd.melt(df, id_vars=['Jurusan'], value_vars=[
    'Kepuasan fasilitas discussion room', 'Kepuasan fasilitas internet',
    'Kepuasan fasilitas kantin', 'Kepuasan fasilitas parkir',
    'Kepuasan fasilitas toilet', 'Kepuasan fasilitas tangga/lift',
    'Kepuasan secara umum'
], var_name='Type', value_name='Value')

data
# Out:
#                          Jurusan                                Type  Value
# 0               Computer Science  Kepuasan fasilitas discussion room      4
# 1               Computer Science  Kepuasan fasilitas discussion room      6
# 2               Computer Science  Kepuasan fasilitas discussion room      4
# 3               Computer Science  Kepuasan fasilitas discussion room      4
# 4               Computer Science  Kepuasan fasilitas discussion room      6
# ..                           ...                                 ...    ...
# 478  Visual Communication Design                Kepuasan secara umum      3
# 479  Visual Communication Design                Kepuasan secara umum      4
# 480  Visual Communication Design                Kepuasan secara umum      5
# 481  Visual Communication Design                Kepuasan secara umum      5
# 482  Visual Communication Design                Kepuasan secara umum      5
#
# [483 rows x 3 columns]

# %%
sns.violinplot(data, y="Value", hue="Type", width=0.7, dodge=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), title='Jenis')
plt.grid(axis='y', linestyle=':')
plt.title("Kepuasan seluruh mahasiswa terhadap semua fasilitas")
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.violinplot(data, y="Value", x="Jurusan", hue="Type", width=0.7, dodge=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), title='Jenis')
plt.grid(axis='y', linestyle=':')
plt.title("Kepuasan mahasiswa jurusan tertentu terhadap semua fasilitas")
plt.show()

# %% [markdown]
# # Corr

# %%
sns.heatmap(pd.crosstab(df['Kepuasan fasilitas internet'][df['Jurusan'] == "Computer Science"], df['Kepuasan fasilitas discussion room'][df['Jurusan'] == "Computer Science"]), annot=True)
# Out:
# <Axes: xlabel='Kepuasan fasilitas discussion room', ylabel='Kepuasan fasilitas internet'>

# %%
internet = df.groupby('Kepuasan fasilitas internet').size().reset_index(name="total")
merged = df.groupby(['Kepuasan fasilitas internet', 'Kepuasan fasilitas discussion room']).size().reset_index(name="count")

merged = merged.merge(internet, on="Kepuasan fasilitas internet", how="left")
merged['perc'] = merged.apply(lambda row:row['count']/row['total'], axis=1)
merged.head()
# Out:
#    Kepuasan fasilitas internet  Kepuasan fasilitas discussion room  count  \
# 0                            1                                   4      3
# 1                            1                                   5      1
# 2                            1                                   6      1
# 3                            2                                   4      2
# 4                            2                                   5      1
#
#    total      perc
# 0      5  0.600000
# 1      5  0.200000
# 2      5  0.200000
# 3      3  0.666667
# 4      3  0.333333

# %%
pivot_df = merged.pivot_table(index='Kepuasan fasilitas internet', columns='Kepuasan fasilitas discussion room', values='perc', fill_value=0)

pivot_df.plot(kind='bar', stacked=True, colormap='viridis', figsize=(10, 7))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), title='Kepuasan fasilitas discussion room')
plt.title("Hubungan kepuasan internet dengan discussion room")
plt.ylabel("Persentase")
plt.yticks([])
plt.plot()
# Out:
# []
