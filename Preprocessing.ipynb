# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset.csv', sep=';')
df.head()
# Out:
#             Jurusan  \
# 0  Computer Science
# 1  Computer Science
# 2  Computer Science
# 3  Computer Science
# 4  Computer Science
#
#   \n\nJenis transportasi apa yang Anda gunakan untuk ke kampus?   \
# 0                                      Motor pribadi
# 1                                      Motor pribadi
# 2                                      Motor pribadi
# 3                                      Motor pribadi
# 4                                      Motor pribadi
#
#   Selama menggunakan fasilitas parkir di Binus, permasalahan apa yang sering Anda jumpai?  \
# 0                                 Antri keluar masuk
# 1                Antri keluar masuk, bayar nya mahal
# 2                    Parkir penuh, Tempatnya terbuka
# 3                   Parkir penuh, Antri keluar masuk
# 4                    Parkir penuh, Tempatnya terbuka
#
#   Menurut Anda fasilitas parkir di Binus Malang sudah aman?\n  \
# 0                                               Aman
# ...

# %%
df.columns
# Out:
# Index(['Jurusan',
#        '\n\nJenis transportasi apa yang Anda gunakan untuk ke kampus? ',
#        'Selama menggunakan fasilitas parkir di Binus, permasalahan apa yang sering Anda jumpai?',
#        'Menurut Anda fasilitas parkir di Binus Malang sudah aman?\n',
#        'Dengan fasilitas yang sudah tersedia, apakah biaya parkir di Binus mahal?',
#        'Seberapa puas Anda dengan fasilitas parkir di Binus Malang?',
#        ' Diantara fasilitas di bawah,  mana yang paling sering anda gunakan?\n',
#        'Kenapa anda lebih memilih fasilitas tersebut?',
#        'Seberapa puas anda dengan fasilitas tangga/lift di Binus Malang?\n\n',
#        'Ketika di kampus, apakah anda lebih sering beli makanan di dalam (kantin binus) atau diluar kampus?',
#        'Kenapa memilih pilihan di atas?',
#        'Seberapa puas anda dengan fasilitas kantin Binus Malang',
#        'Apakah anda sering menggunakan fasilitas discussion room (arjuno)?',
# ...

# %%
rename = {}

newName = [
    'Jurusan',
    'Jenis transportasi yang digunakan',
    'Permasalahan fasilitas parkir ',
    'Keamanan fasilitas parkir',
    'Biaya parkir',
    'Kepuasan fasilitas parkir',
    'Tangga/lift yang paling sering dipakai',
    'Alasan lebih memilih fasilitas tersebut',
    'Kepuasan terhadap fasilitas tangga/lift',
    'Lokasi beli makanan',
    'Alasan memilih beli di tempat itu',
    'Seberapa puas anda dengan fasilitas kantin Binus Malang',
    'Apakah anda sering menggunakan fasilitas discussion room (arjuno)?',
    'Selama menggunakan fasilitas discussion room, permasalahan apa yang sering anda\njumpai?',
    'Seberapa puas anda dengan fasilitas discussion room?',
    'Apakah wifi di Binus sudah cepat dan stabil?',
    'Seberapa puas Anda dengan fasilitas internet di Binus Malang?',
    'Apakah kapasitas toilet di Binus Malang sudah memadai?',
    'Apakah toilet di Binus Malang sudah bersih?',
    'Seberapa puas Anda dengan fasilitas toilet di Binus Malang?',
    'Seberapa puas anda dengan seluruh fasilitas Binus Malang?'
]

for i in range(len(df.columns)):
    rename[col] =
